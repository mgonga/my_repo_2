# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df= pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
#1 
demographics= df[ df["gender"].isin(['Male']) ]
demographics
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE   Male              0      No         No      34
# 2     3668-QPYBK   Male              0      No         No       2
# 3     7795-CFOCW   Male              0      No         No      45
# 6     1452-KIOVK   Male              0      No        Yes      22
# 9     6388-TABGU   Male              0      No        Yes      62
# ...          ...    ...            ...     ...        ...     ...
# 7033  9767-FFLEM   Male              0      No         No      38
# 7035  8456-QDAVC   Male              0      No         No      19
# 7038  6840-RESVB   Male              0     Yes        Yes      24
# 7041  8361-LTMKD   Male              1     Yes         No       4
# 7042  3186-AJIEK   Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1             Yes                No             DSL            Yes  ...
# ...

# %%
df.SeniorCitizen = df.SeniorCitizen.replace({1: True, 0: False})
df.SeniorCitizen
Senior_Citizen = df.SeniorCitizen[df.SeniorCitizen==False].count()
Senior_Citizen
# Out:
# 5901

# %%
marriage_status= df[ df["Partner"].isin(['No']) ]
marriage_status
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE    Male          False      No         No      34
# 2     3668-QPYBK    Male          False      No         No       2
# 3     7795-CFOCW    Male          False      No         No      45
# 4     9237-HQITU  Female          False      No         No       2
# 5     9305-CDSKC  Female          False      No         No       8
# ...          ...     ...            ...     ...        ...     ...
# 7034  0639-TSIQW  Female          False      No         No      67
# 7035  8456-QDAVC    Male          False      No         No      19
# 7036  7750-EYXWZ  Female          False      No         No      12
# 7037  2569-WGERO  Female          False      No         No      72
# 7042  3186-AJIEK    Male          False      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1             Yes                No             DSL                  Yes  ...
# ...

# %%
#2
customer_retention = df[ df["Churn"].isin(['Yes']) ]
customer_retention
df_2 =customer_retention
Senior_Citizen_2 = df_2.SeniorCitizen[df_2.SeniorCitizen==False].count()
Senior_Citizen_2
# Out:
# 1393

# %%
seniorcitizen = df_2[df_2["gender"].isin(['Male']) ]
seniorcitizen
df_3 = seniorcitizen
seniorcitizen= df_3.SeniorCitizen[df_3.SeniorCitizen==False].count()
seniorcitizen
# Out:
# 694

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female          False     Yes         No       1           No
# 1  5575-GNVDE    Male          False      No         No      34          Yes
# 2  3668-QPYBK    Male          False      No         No       2          Yes
# 3  7795-CFOCW    Male          False      No         No      45           No
# 4  9237-HQITU  Female          False      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
#2 (a)
Contract_month= df[ df["Contract"].isin(['Month-to-month']) ]
Contract_month
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female          False     Yes         No       1
# 2     3668-QPYBK    Male          False      No         No       2
# 4     9237-HQITU  Female          False      No         No       2
# 5     9305-CDSKC  Female          False      No         No       8
# 6     1452-KIOVK    Male          False      No        Yes      22
# ...          ...     ...            ...     ...        ...     ...
# 7033  9767-FFLEM    Male          False      No         No      38
# 7034  0639-TSIQW  Female          False      No         No      67
# 7035  8456-QDAVC    Male          False      No         No      19
# 7040  4801-JZAZL  Female          False     Yes        Yes      11
# 7041  8361-LTMKD    Male           True     Yes         No       4
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
Churned_customers = df[ df["Churn"].isin(['Yes']) ]
Churned_customers
df_churned = Churned_customers[Churned_customers["StreamingTV"].isin(['Yes'])]
df_churned
ChurnedCustomers = df_churned
ChurnedCustomers.describe()
# Out:
#            tenure  MonthlyCharges
# count  814.000000      814.000000
# mean    25.840295       90.497359
# std     21.632547       16.843545
# min      1.000000       34.000000
# 25%      7.000000       85.150000
# 50%     20.000000       94.975000
# 75%     43.000000      101.137500
# max     72.000000      118.350000

# %%
df_Internetservice=df.groupby(["Churn", "InternetService"])["MonthlyCharges"].nunique().reset_index()
plt.figure(figsize=(15,10))
sns.barplot(x="Churn", y="MonthlyCharges", hue="InternetService", data=df)
plt.title("InternetServiceChurned")
plt.xlabel("Churn")
plt.ylabel("MonthlyCharges")
# Out:
# Text(0, 0.5, 'MonthlyCharges')

# %%
df_Internetservice=df.groupby(["Churn", "PhoneService"])["MonthlyCharges"].nunique().reset_index()
plt.figure(figsize=(15,10))
sns.barplot(x="Churn", y="MonthlyCharges", hue="PhoneService", data=df)
plt.title("PhoneServiceChurned")
plt.xlabel("Churn")
plt.ylabel("MonthlyCharges")
# Out:
# Text(0, 0.5, 'MonthlyCharges')

# %%
df_streamingmovies=df.groupby(["Churn", "StreamingMovies"])["MonthlyCharges"].nunique().reset_index()
plt.figure(figsize=(15,10))
sns.barplot(x="Churn", y="MonthlyCharges", hue="StreamingMovies", data=df)
plt.title("StreamingChurned")
plt.xlabel("Churn")
plt.ylabel("MonthlyCharges")
# Out:
# Text(0, 0.5, 'MonthlyCharges')

# %%
#(b)
contract_type = df[ df["PhoneService"].isin(['Yes']) ]
contract_type
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE    Male          False      No         No      34
# 2     3668-QPYBK    Male          False      No         No       2
# 4     9237-HQITU  Female          False      No         No       2
# 5     9305-CDSKC  Female          False      No         No       8
# 6     1452-KIOVK    Male          False      No        Yes      22
# ...          ...     ...            ...     ...        ...     ...
# 7037  2569-WGERO  Female          False      No         No      72
# 7038  6840-RESVB    Male          False     Yes        Yes      24
# 7039  2234-XADUH  Female          False     Yes        Yes      72
# 7041  8361-LTMKD    Male           True     Yes         No       4
# 7042  3186-AJIEK    Male          False      No         No      66
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 1             Yes            No             DSL                  Yes  ...
# ...

# %%
customer_retention = contract_type 
customer_retention
contract_retention = customer_retention [ customer_retention["Contract"].isin(['Month-to-month']) ]
contract_retention
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2     3668-QPYBK    Male          False      No         No       2
# 4     9237-HQITU  Female          False      No         No       2
# 5     9305-CDSKC  Female          False      No         No       8
# 6     1452-KIOVK    Male          False      No        Yes      22
# 8     7892-POOKP  Female          False     Yes         No      28
# ...          ...     ...            ...     ...        ...     ...
# 7032  6894-LFHLY    Male           True      No         No       1
# 7033  9767-FFLEM    Male          False      No         No      38
# 7034  0639-TSIQW  Female          False      No         No      67
# 7035  8456-QDAVC    Male          False      No         No      19
# 7041  8361-LTMKD    Male           True     Yes         No       4
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 2             Yes            No             DSL            Yes  ...
# ...

# %%
#3 (a)

# %%
# (b)
payment =  df[ df["Contract"].isin(['Month-to-month']) ]
payment
contract_payment = payment
contract_payment
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female          False     Yes         No       1
# 2     3668-QPYBK    Male          False      No         No       2
# 4     9237-HQITU  Female          False      No         No       2
# 5     9305-CDSKC  Female          False      No         No       8
# 6     1452-KIOVK    Male          False      No        Yes      22
# ...          ...     ...            ...     ...        ...     ...
# 7033  9767-FFLEM    Male          False      No         No      38
# 7034  0639-TSIQW  Female          False      No         No      67
# 7035  8456-QDAVC    Male          False      No         No      19
# 7040  4801-JZAZL  Female          False     Yes        Yes      11
# 7041  8361-LTMKD    Male           True     Yes         No       4
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
payment_method = contract_payment[contract_payment ["PaymentMethod"].isin(['Mailed check']) ]
payment_method 
churn_mailed = payment_method
churn_mailed
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2     3668-QPYBK    Male          False      No         No       2
# 7     6713-OKOMC  Female          False      No         No      10
# 10    9763-GRSKD    Male          False     Yes        Yes      13
# 22    1066-JKSGK    Male          False      No         No       1
# 29    8773-HHUOZ  Female          False      No        Yes      17
# ...          ...     ...            ...     ...        ...     ...
# 7011  5482-NUPNA  Female          False      No         No       4
# 7018  1122-JWTJW    Male          False     Yes        Yes       1
# 7027  0550-DCXLH    Male          False      No         No      13
# 7030  0871-OPBXW  Female          False      No         No       2
# 7041  8361-LTMKD    Male           True     Yes         No       4
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 2             Yes                No             DSL                  Yes  ...
# ...

# %%
churn_mailed_check = churn_mailed[churn_mailed["Churn"].isin(['Yes']) ]
churn_mailed_check
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2     3668-QPYBK    Male          False      No         No       2
# 22    1066-JKSGK    Male          False      No         No       1
# 29    8773-HHUOZ  Female          False      No        Yes      17
# 97    0278-YXOOG    Male          False      No         No       5
# 139   0390-DCFDQ  Female           True     Yes         No       1
# ...          ...     ...            ...     ...        ...     ...
# 6999  2108-XWMPY    Male          False      No         No       3
# 7001  6304-IJFSQ    Male          False      No         No       3
# 7011  5482-NUPNA  Female          False      No         No       4
# 7018  1122-JWTJW    Male          False     Yes        Yes       1
# 7041  8361-LTMKD    Male           True     Yes         No       4
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 2             Yes                No             DSL                  Yes  ...
# ...

# %%
# The company should strictly go paperless because amongst the customers that mail their checks a good number of them can be or will be reteined.
