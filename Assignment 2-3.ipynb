# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df= pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
Attrition= df['Attrition']
Attrition.head()
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3     No
# 4     No
# Name: Attrition, dtype: object

# %%
print(type(df['Attrition']))
df['Attrition'].shape
# Out:
# <class 'pandas.core.series.Series'>
# (1470,)

# %%
Attrition= df[ df["Attrition"].isin(['Yes']) ]
Attrition
employee_attrition = Attrition
employee_attrition
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 21     36       Yes      Travel_Rarely       1218                   Sales
# 24     34       Yes      Travel_Rarely        699  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1438   23       Yes  Travel_Frequently        638                   Sales
# 1442   29       Yes      Travel_Rarely       1092  Research & Development
# 1444   56       Yes      Travel_Rarely        310  Research & Development
# 1452   50       Yes  Travel_Frequently        878                   Sales
# 1461   50       Yes      Travel_Rarely        410                   Sales
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
Travelling_attrition = employee_attrition[employee_attrition ["BusinessTravel"].isin(['Travel_Rarely']) ]
Travelling_attrition
#Out of 237 people that attrited, 156 rarely traavelled so it might a factor that led to that.
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 0      41       Yes  Travel_Rarely       1102                   Sales
# 2      37       Yes  Travel_Rarely       1373  Research & Development
# 14     28       Yes  Travel_Rarely        103  Research & Development
# 21     36       Yes  Travel_Rarely       1218                   Sales
# 24     34       Yes  Travel_Rarely        699  Research & Development
# ...   ...       ...            ...        ...                     ...
# 1390   28       Yes  Travel_Rarely       1404  Research & Development
# 1396   53       Yes  Travel_Rarely       1168                   Sales
# 1442   29       Yes  Travel_Rarely       1092  Research & Development
# 1444   56       Yes  Travel_Rarely        310  Research & Development
# 1461   50       Yes  Travel_Rarely        410                   Sales
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
MonthlyIncome_attrition = employee_attrition[employee_attrition ["BusinessTravel"].isin(['Travel_Rarely']) ]
MonthlyIncome_attrition
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 0      41       Yes  Travel_Rarely       1102                   Sales
# 2      37       Yes  Travel_Rarely       1373  Research & Development
# 14     28       Yes  Travel_Rarely        103  Research & Development
# 21     36       Yes  Travel_Rarely       1218                   Sales
# 24     34       Yes  Travel_Rarely        699  Research & Development
# ...   ...       ...            ...        ...                     ...
# 1390   28       Yes  Travel_Rarely       1404  Research & Development
# 1396   53       Yes  Travel_Rarely       1168                   Sales
# 1442   29       Yes  Travel_Rarely       1092  Research & Development
# 1444   56       Yes  Travel_Rarely        310  Research & Development
# 1461   50       Yes  Travel_Rarely        410                   Sales
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
MonthlyIncome = df['MonthlyIncome']
MonthlyIncome.describe()
# Out:
# count     1470.000000
# mean      6502.931293
# std       4707.956783
# min       1009.000000
# 25%       2911.000000
# 50%       4919.000000
# 75%       8379.000000
# max      19999.000000
# Name: MonthlyIncome, dtype: float64

# %%
paid_below_average = employee_attrition[employee_attrition["MonthlyIncome"] <6503]
paid_below_average
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 21     36       Yes      Travel_Rarely       1218                   Sales
# 24     34       Yes      Travel_Rarely        699  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1390   28       Yes      Travel_Rarely       1404  Research & Development
# 1395   31       Yes  Travel_Frequently        754                   Sales
# 1438   23       Yes  Travel_Frequently        638                   Sales
# 1442   29       Yes      Travel_Rarely       1092  Research & Development
# 1444   56       Yes      Travel_Rarely        310  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
paid_below_average.count()
#185 customers were paid below the average monthly income. So monthly income also led to attrition.
# Out:
# Age                         185
# Attrition                   185
# BusinessTravel              185
# DailyRate                   185
# Department                  185
# DistanceFromHome            185
# Education                   185
# EducationField              185
# EmployeeCount               185
# EmployeeNumber              185
# EnvironmentSatisfaction     185
# Gender                      185
# HourlyRate                  185
# JobInvolvement              185
# JobLevel                    185
# JobRole                     185
# JobSatisfaction             185
# MaritalStatus               185
# MonthlyIncome               185
# MonthlyRate                 185
# NumCompaniesWorked          185
# Over18                      185
# OverTime                    185
# PercentSalaryHike           185
# PerformanceRating           185
# RelationshipSatisfaction    185
# StandardHours               185
# StockOptionLevel            185
# TotalWorkingYears           185
# ...

# %%
DistanceFromHome_attrition = employee_attrition[employee_attrition["StockOptionLevel"] < 1]
DistanceFromHome_attrition
#Stock option level was the other factor that led to employee attrition.
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 21     36       Yes      Travel_Rarely       1218                   Sales
# 24     34       Yes      Travel_Rarely        699  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1369   28       Yes      Travel_Rarely       1475                   Sales
# 1375   32       Yes  Travel_Frequently        238  Research & Development
# 1379   27       Yes  Travel_Frequently       1337         Human Resources
# 1395   31       Yes  Travel_Frequently        754                   Sales
# 1396   53       Yes      Travel_Rarely       1168                   Sales
#
#       DistanceFromHome  Education   EducationField  EmployeeCount  \
# ...

# %%
DistanceFromHome = Attrition_2['DistanceFromHome']
DistanceFromHome.describe()
# Out:
# count    237.000000
# mean      10.632911
# std        8.452525
# min        1.000000
# 25%        3.000000
# 50%        9.000000
# 75%       17.000000
# max       29.000000
# Name: DistanceFromHome, dtype: float64

# %%
Attrition_2= df[ df["Attrition"].isin(['Yes']) ]
Attrition_2 
DistanceFromHome_2 = Attrition_2
DistanceFromHome_2
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 21     36       Yes      Travel_Rarely       1218                   Sales
# 24     34       Yes      Travel_Rarely        699  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1438   23       Yes  Travel_Frequently        638                   Sales
# 1442   29       Yes      Travel_Rarely       1092  Research & Development
# 1444   56       Yes      Travel_Rarely        310  Research & Development
# 1452   50       Yes  Travel_Frequently        878                   Sales
# 1461   50       Yes      Travel_Rarely        410                   Sales
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
DistanceFromHome_byattrition = DistanceFromHome_2[DistanceFromHome_2["DistanceFromHome"] < 15]
DistanceFromHome_byattrition
#Amongst employees who attrited, msot of them worked close to home.
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 21     36       Yes      Travel_Rarely       1218                   Sales
# 24     34       Yes      Travel_Rarely        699  Research & Development
# 33     39       Yes      Travel_Rarely        895                   Sales
# ...   ...       ...                ...        ...                     ...
# 1375   32       Yes  Travel_Frequently        238  Research & Development
# 1438   23       Yes  Travel_Frequently        638                   Sales
# 1442   29       Yes      Travel_Rarely       1092  Research & Development
# 1444   56       Yes      Travel_Rarely        310  Research & Development
# 1452   50       Yes  Travel_Frequently        878                   Sales
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
JobRole = df['JobRole']
JobRole
# Out:
# 0                 Sales Executive
# 1              Research Scientist
# 2           Laboratory Technician
# 3              Research Scientist
# 4           Laboratory Technician
#                   ...
# 1465        Laboratory Technician
# 1466    Healthcare Representative
# 1467       Manufacturing Director
# 1468              Sales Executive
# 1469        Laboratory Technician
# Name: JobRole, Length: 1470, dtype: object

# %%
df["JobRole"].value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
jobrole= df[ df["JobRole"].isin(['Human Resources']) ]
jobrole
distncefromhome_jobrole = jobrole
distncefromhome_jobrole
# Out:
#       Age Attrition     BusinessTravel  DailyRate       Department  \
# 79     46        No      Travel_Rarely        945  Human Resources
# 100    37       Yes      Travel_Rarely        807  Human Resources
# 134    26        No      Travel_Rarely       1355  Human Resources
# 139    30        No      Travel_Rarely       1240  Human Resources
# 232    59        No      Travel_Rarely        818  Human Resources
# 310    31        No      Travel_Rarely        106  Human Resources
# 350    42        No      Travel_Rarely        544  Human Resources
# 422    19       Yes      Travel_Rarely        489  Human Resources
# 440    34       Yes  Travel_Frequently        988  Human Resources
# 453    26       Yes  Travel_Frequently        426  Human Resources
# 493    44        No      Travel_Rarely       1112  Human Resources
# 510    54        No      Travel_Rarely        397  Human Resources
# 551    39        No      Travel_Rarely        141  Human Resources
# ...

# %%
distncefromhome_jobrole = distncefromhome_jobrole[distncefromhome_jobrole["DistanceFromHome"] < 15]
distncefromhome_jobrole.head()
# Out:
#      Age Attrition BusinessTravel  DailyRate       Department  \
# 79    46        No  Travel_Rarely        945  Human Resources
# 100   37       Yes  Travel_Rarely        807  Human Resources
# 139   30        No  Travel_Rarely       1240  Human Resources
# 232   59        No  Travel_Rarely        818  Human Resources
# 310   31        No  Travel_Rarely        106  Human Resources
#
#      DistanceFromHome  Education   EducationField  EmployeeCount  \
# 79                  5          2          Medical              1
# 100                 6          4  Human Resources              1
# 139                 9          3  Human Resources              1
# 232                 6          2          Medical              1
# 310                 2          3  Human Resources              1
#
#      EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 79              103  ...                         4            80
# 100             133  ...                         4            80
# ...

# %%
#According to calculations in percentages, Research Scientists stayed worked close to home or had little distance from home.

# %%
MonthlyIncome  = df['MonthlyIncome']
MonthlyIncome .describe()
#Average monthly income is 6503
# Out:
# count     1470.000000
# mean      6502.931293
# std       4707.956783
# min       1009.000000
# 25%       2911.000000
# 50%       4919.000000
# 75%       8379.000000
# max      19999.000000
# Name: MonthlyIncome, dtype: float64

# %%
average_income = df[df["MonthlyIncome"] > 6503]
average_income
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 8      38        No  Travel_Frequently        216  Research & Development
# 15     29        No      Travel_Rarely       1389  Research & Development
# 18     53        No      Travel_Rarely       1219                   Sales
# 22     34        No      Travel_Rarely        419  Research & Development
# 25     53        No      Travel_Rarely       1282  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1453   36        No      Travel_Rarely       1120                   Sales
# 1461   50       Yes      Travel_Rarely        410                   Sales
# 1462   39        No      Travel_Rarely        722                   Sales
# 1463   31        No         Non-Travel        325  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
Education  = df['Education']
Education.describe()
# Out:
# count    1470.000000
# mean        2.912925
# std         1.024165
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# Name: Education, dtype: float64

# %%
monthly_average = average_income
monthly_average
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 8      38        No  Travel_Frequently        216  Research & Development
# 15     29        No      Travel_Rarely       1389  Research & Development
# 18     53        No      Travel_Rarely       1219                   Sales
# 22     34        No      Travel_Rarely        419  Research & Development
# 25     53        No      Travel_Rarely       1282  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1453   36        No      Travel_Rarely       1120                   Sales
# 1461   50       Yes      Travel_Rarely        410                   Sales
# 1462   39        No      Travel_Rarely        722                   Sales
# 1463   31        No         Non-Travel        325  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
monthly_average_income = monthly_average[monthly_average["Education"] == 5]
monthly_average_income.head()
#Out of 493 employees who received more than the average monthly salary, 5 % had the best education. In conclusion, the better education an employee had the better the average monthly salary.
# Out:
#      Age Attrition     BusinessTravel  DailyRate              Department  \
# 56    35        No  Travel_Frequently        853                   Sales
# 151   35        No      Travel_Rarely        662                   Sales
# 329   47        No      Travel_Rarely       1482  Research & Development
# 348   42        No      Travel_Rarely        810  Research & Development
# 358   36        No         Non-Travel        845                   Sales
#
#      DistanceFromHome  Education EducationField  EmployeeCount  \
# 56                 18          5  Life Sciences              1
# 151                 1          5      Marketing              1
# 329                 5          5  Life Sciences              1
# 348                23          5  Life Sciences              1
# 358                 1          5        Medical              1
#
#      EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 56               74  ...                         4            80
# ...

# %%
income = df[ df["Attrition"].isin(['Yes']) ]
income
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 21     36       Yes      Travel_Rarely       1218                   Sales
# 24     34       Yes      Travel_Rarely        699  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1438   23       Yes  Travel_Frequently        638                   Sales
# 1442   29       Yes      Travel_Rarely       1092  Research & Development
# 1444   56       Yes      Travel_Rarely        310  Research & Development
# 1452   50       Yes  Travel_Frequently        878                   Sales
# 1461   50       Yes      Travel_Rarely        410                   Sales
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
income_average = income
income_average
income_monthly_average = income_average[income_average["MonthlyIncome"] < 6503]
income_monthly_average
# More than half of the employees that attriteed earned less than average monthly income.
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 21     36       Yes      Travel_Rarely       1218                   Sales
# 24     34       Yes      Travel_Rarely        699  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1390   28       Yes      Travel_Rarely       1404  Research & Development
# 1395   31       Yes  Travel_Frequently        754                   Sales
# 1438   23       Yes  Travel_Frequently        638                   Sales
# 1442   29       Yes      Travel_Rarely       1092  Research & Development
# 1444   56       Yes      Travel_Rarely        310  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
#ASSIGNMENT 3

# %%
df_streamingmovies=df.groupby(["Attrition", "JobRole"])["DistanceFromHome"].nunique().reset_index()
plt.figure(figsize=(15,10))
sns.barplot(x="Attrition", y="DistanceFromHome", hue="JobRole", data=df)
plt.title("Distance by JobRole")
plt.xlabel("Attrition")
plt.ylabel("DistanceFromHome")
# Out:
# Text(0, 0.5, 'DistanceFromHome')

# %%
df_=df.groupby(["Attrition", "Education"])["MonthlyIncome"].nunique().reset_index()
plt.figure(figsize=(15,10))
sns.barplot(x="Attrition", y="MonthlyIncome", hue="Education", data=df)
plt.title("Monthly Income By Education")
plt.xlabel("Attrition")
plt.ylabel("MonthlyIncome")
# Out:
# Text(0, 0.5, 'MonthlyIncome')

# %%
df_average_monthlyincome=df.groupby(["Attrition", "Education"])["MonthlyIncome"].nunique().reset_index()
plt.figure(figsize=(15,10))
sns.barplot(x="Attrition", y="MonthlyIncome", hue="Education", data=df)
plt.title("Monthly Income By Education and Attrition")
plt.xlabel("Attrition")
plt.ylabel("MonthlyIncome")
# Out:
# Text(0, 0.5, 'MonthlyIncome')
